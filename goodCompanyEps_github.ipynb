# %%
import pandas as pd
import numpy as np

data=pd.read_csv(r'dataOriginalCsv/companyEPS.csv') # ,encoding='utf-8' 如果無法讀要先用txt轉檔
# https://www.796t.com/post/MjJid3M=.html
print("info():",data.info())
print(data)

# print('=======----------')

#def csv_2_xlsx(srcPath):
   # try:
   #    data = pd.DataFrame(pd.read_csv(srcPath, encoding='utf8', low_memory=False))
   # except:
   #     data = pd.DataFrame(pd.read_csv(srcPath, encoding='gbk', low_memory=False))
   # data.to_excel(srcPath[:-3] + 'xlsx', sheet_name='Sheet1', index=False)

# 缺失值填充
# data = data1.fillna(0)
# data

# %%
# 消除數字間的逗號 
data['稅後淨利']=data['稅後淨利'].str.replace(',','')
print(data['稅後淨利'])

# 將型態object轉成int 
data['稅後淨利']=pd.to_numeric(data['稅後淨利'], errors='coerce').fillna('0').astype('int64')
print(data['稅後淨利'])

# %%
# 篩選需要的數據
filt = data['稅後淨利']>=0
print(data.loc[filt])

# d1=data.loc[:,['稅後淨利']]
# print("d1:",d1)
# d2=data.loc[filt]
# print("d2:",d2)

# data.loc可提取指定行數據 並印出想要的列
dataAll=data.loc[filt, ['公司代號', '公司名稱', '稅後淨利']]
print("提取指定行數據:",dataAll)

# 刪除重複欄位
dataAll = dataAll.drop_duplicates(subset='公司代號')
print("刪除重複欄位:",dataAll)

# 刪除缺失值
dataAll=dataAll.dropna()
print("刪除缺失值:",len(dataAll))

# %%
dataAll.to_csv('dataPause/companyEPS_new.csv', index=False)

# %%
from selenium import webdriver  # 操作 browser 的 API
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait  # 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support import expected_conditions as EC  # 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.common.by import By  # 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from time import sleep  # 強制等待 (執行期間休息一下)

import pandas as pd
import numpy as np
import json  # 整理 json 使用的工具
import os, csv, re  # 執行 command 的時候用的

# 啟動瀏覽器工具的選項
options = webdriver.ChromeOptions()
# options.add_argument("--headless")              # 不開啟實體瀏覽器背景執行
options.add_argument("--start-maximized")         # 最大化視窗
options.add_argument("--incognito")               # 開啟無痕模式
options.add_argument("--disable-popup-blocking ") # 禁用彈出攔截

# 使用 Chrome 的 WebDriver (含 options)
driver = webdriver.Chrome( options = options )

empty1=""
input1="1101"
url ='https://mops.twse.com.tw/mops/web/stapap1'

aveEpsth = ['公司名稱','職稱','姓名', '選任時持股', '目前持股', '設質股數', '設質股數佔持股比','目前持股合計','設質股數', '設質比例']
aveNum=len(aveEpsth)-1

def visit():
    # 前往指定連結
    global writeCount
    a=0
    writeCount=0
    driver.get(url)  
    f=open("dataPause/companyEPS_new.csv",encoding="utf8") 
    
    readCsv=pd.read_csv(f)
    dfCsv=pd.DataFrame(readCsv)
    
    df_ch=dfCsv['公司代號'].values.tolist()
    df_name=dfCsv['公司名稱'].values.tolist()
    
    print(len(df_ch))

        
    for df in df_ch:
        
        search(df)
        a+=1
        print("第筆:",a)
        print(df)
        downloadData(df,df_name)
        writeCount+=1
        #print(tdContent)
        
        #清空值
        driver.find_element(By.CSS_SELECTOR, "input[name='co_id'].textbox").clear()
            
        if a == len(df_ch):
            
            print("-------------")
            print("爬蟲結束")

     
    
def search(df): #search(df)
       
    txtInput = driver.find_element(By.CSS_SELECTOR, "input[name='co_id'].textbox")
    txtInput.send_keys(df)
    sleep(3)
    
    btnInput = driver.find_element(By.CSS_SELECTOR, "div.search input[type='button']")
    btnInput.click()
    sleep(3)
    
    
def downloadData(df,df_name):

    global th1,th2, tdContent1,tdContent2,thText,pp 
    
    thText=["公司名稱"]
    
    td1 = driver.find_elements(By.CSS_SELECTOR, "table.hasBorder tbody tr.odd td")  # html內基數行
    td2 = driver.find_elements(By.CSS_SELECTOR, "table.hasBorder tbody tr.even td")  # html內偶數行
           
    tdContent1 = [n.get_attribute('innerHTML').strip() for n in td1]
    tdContent2 = [n.get_attribute('innerHTML').strip() for n in td2]    

    th1 = tdContent1[:aveNum]
    th2 = tdContent2[:aveNum]    
    pp=df
    
    for j in thText:
        th1.insert(0, j)
        th2.insert(0, j)
        print("**************")
        print(th1)
        print(th2)
    print("*&&&&&&&&&&&&&&&&*")
    print(df_name[0])
        
    saveCsv(pp,df_name)
    
def saveCsv(pp,df_name):
    folderPath = 'covidInfo'
    if not os.path.exists(folderPath):
        os.makedirs(folderPath)
            
    with open(f"{folderPath}/comNewAllNew123456.csv", 'a', newline = '', encoding = 'utf-8') as csvfile:
        writer = csv.writer(csvfile)
        if writeCount == 0:
            writer.writerow(aveEpsth)
        
        print(len(tdContent1))
        print(len(tdContent2))  
        print("###############")
        print(pp)
        
        for i in range(0, len(tdContent1),aveNum):
                        
            c1 = tdContent1[i:i+aveNum]
            c2 = tdContent2[i:i+aveNum]
            
            # 因為不確定每個表格的基數偶數的行數量 所以用=0表示無此行
            if len(c1)==0 or len(c2)==0:
                print("沒有此行")
            else:   
                thText=str(pp)+' '+df_name[writeCount]
                c1.insert(0, thText)
                c2.insert(0, thText)
                writer.writerow(c1)
                writer.writerow(c2)
                
            print("((((((((()))))))))")   
            print(c1)
            print(c2)
        
    csvfile.close()
    
if __name__ == '__main__':
    visit()
    
driver.quit()
# Out:
# 2304
# 第筆: 1
# 1102
# **************
# ['公司名稱', '董事長本人', '徐旭東', '23,278,334', '23,278,334', '0', '0.00%', '6,352,467', '0', '0.00%']
# ['公司名稱', '董事本人', '遠東新世紀股份有限公司', '750,511,324', '750,511,324', '19,900,000', '2.65%', '0', '0', '0.00%']
# *&&&&&&&&&&&&&&&&*
# 亞洲水泥股份有限公司
# 180
# 180
# ###############
# 1102
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事長本人', '徐旭東', '23,278,334', '23,278,334', '0', '0.00%', '6,352,467', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '遠東新世紀股份有限公司', '750,511,324', '750,511,324', '19,900,000', '2.65%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '席家宜', '0', '453,745', '0', '0.00%', '6,676,993', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '遠東新世紀股份有限公司', '750,511,324', '750,511,324', '19,900,000', '2.65%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '張才雄', '0', '459,350', '0', '0.00%', '110,877', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '遠東新世紀股份有限公司', '750,511,324', '750,511,324', '19,900,000', '2.65%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '陳長文', '0', '338,429', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '裕鼎實業股份有限公司', '1,895,136', '1,895,136', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '李坤炎', '0', '2,361,557', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '大聚化學纖維股份有限公司', '1,560,068', '1,560,068', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '陳瑞隆', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '醫療財團法人徐元智先生醫藥基金會', '181,566,797', '181,566,797', '24,500,000', '13.49%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '李冠軍', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '財團法人徐有庠先生紀念基金會', '6,218,800', '6,218,800', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '徐旭平', '0', '13,454,981', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '財團法人徐有庠先生紀念基金會', '6,218,800', '6,218,800', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '張振崑', '0', '29,745', '0', '0.00%', '5,358', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '百揚投資股份有限公司', '3,849,468', '3,849,468', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '歐晉德', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '董事本人', '裕民股份有限公司', '1,505,585', '1,505,585', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '董事之法人代表人', '李光燾', '0', '642,936', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '獨立董事本人', '朱雲鵬', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '獨立董事本人', '薛琦', '20,000', '0', '0', '0.00%', '10,000', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '獨立董事本人', '陳樹', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '總經理本人', '李坤炎', '0', '2,361,557', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '副總經理本人', '余東霖', '0', '122,202', '0', '0.00%', '98', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '副總經理本人', '張志鵬', '0', '33,999', '0', '0.00%', '53,588', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '副總經理本人', '吳玲綾', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '副總經理本人', '陳春明', '0', '39,801', '0', '0.00%', '68,596', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '副總經理本人', '周維崑', '0', '4,962', '0', '0.00%', '4,962', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '協理本人', '高雪英', '0', '832', '0', '0.00%', '467', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '協理本人', '陳聰明', '0', '147,268', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '協理本人', '葉文華', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '協理本人', '王照宇', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '協理本人', '李洪慧', '0', '8,971', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '協理本人', '楊淯玲', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '協理本人', '李雅萍', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '大股東本人', '遠東新世紀股份有限公司', '0', '750,511,324', '19,900,000', '2.65%', '0', '0', '0.00%']
# ((((((((()))))))))
# ['1102 亞洲水泥股份有限公司', '財務部門主管本人', '吳玲綾', '0', '0', '0', '0.00%', '0', '0', '0.00%']
# ['1102 亞洲水泥股份有限公司', '會計部門主管本人', '高雪英', '0', '832', '0', '0.00%', '467', '0', '0.00%']
# 第筆: 2
# 1101
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3368/778814285.py in <module>
#     140
#     141 if __name__ == '__main__':
# --> 142     visit()
#     143
#     144 driver.quit()
#
# ~\AppData\Local\Temp/ipykernel_3368/778814285.py in visit()
#      51         print("第筆:",a)
#      52         print(df)
# ---> 53         downloadData(df,df_name)
#      54         writeCount+=1
#      55         #print(tdContent)
#
# ~\AppData\Local\Temp/ipykernel_3368/778814285.py in downloadData(df, df_name)
#      82     thText=["公司名稱"]
#      83
# ---> 84     td1 = driver.find_elements(By.CSS_SELECTOR, "table.hasBorder tbody tr.odd td")  # html內基數行
#      85     td2 = driver.find_elements(By.CSS_SELECTOR, "table.hasBorder tbody tr.even td")  # html內偶數行
#      86
#
# ~\anaconda3\envs\LuvPython\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1281         # Return empty list if driver returns null
#    1282         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1283         return self.execute(Command.FIND_ELEMENTS, {
#    1284             'using': by,
#    1285             'value': value})['value'] or []
#
# ~\anaconda3\envs\LuvPython\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\envs\LuvPython\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=100.0.4896.75)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008A7413+2389011]
# 	Ordinal0 [0x00839F61+1941345]
# 	Ordinal0 [0x0072C520+836896]
# 	Ordinal0 [0x00720682+788098]
# 	Ordinal0 [0x00720EB8+790200]
# 	Ordinal0 [0x00722752+796498]
# 	Ordinal0 [0x0071C0D9+770265]
# 	Ordinal0 [0x0072D9D0+842192]
# 	Ordinal0 [0x00783AE2+1194722]
# 	Ordinal0 [0x00773F66+1130342]
# 	Ordinal0 [0x0074E546+976198]
# 	Ordinal0 [0x0074F456+980054]
# 	GetHandleVerifier [0x00A59632+1727522]
# 	GetHandleVerifier [0x00B0BA4D+2457661]
# 	GetHandleVerifier [0x0093EB81+569713]
# 	GetHandleVerifier [0x0093DD76+566118]
# 	Ordinal0 [0x00840B2B+1968939]
# 	Ordinal0 [0x00845988+1989000]
# 	Ordinal0 [0x00845A75+1989237]
# 	Ordinal0 [0x0084ECB1+2026673]
# 	BaseThreadInitThunk [0x76B7FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77727A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77727A4E+238]
